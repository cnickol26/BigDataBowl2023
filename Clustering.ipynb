# %%
import pandas as pd
import numpy as np
import pymc as pm

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('https://media.githubusercontent.com/media/cnickol26/BigDataBowl2023/main/cluster_data.csv')

# %%
data
# Out:
#         uniqueplayId  QB_Flip  end_too_far  perc_tackle_lt_1.5  \
# 0       202109090097      0.0            0           -0.139697
# 1       202109090097      1.0            0            0.517118
# 2       202109120163      0.0            0           -0.071583
# 3       202109120163      1.0            0           -0.256464
# 4       202109120288      0.0            0            0.659903
# ...              ...      ...          ...                 ...
# 9653  20211025003684      1.0            0            0.664244
# 9654  20211025003904      0.0            0            1.962110
# 9655  20211025003904      1.0            0            0.351855
# 9656  20211025003926      0.0            0            1.497757
# 9657  20211025003926      1.0            0            1.149493
#
#       perc_tackl_end_facing  End_dist_travel  Max_end_speed
# 0                  0.087154         1.266366       1.088564
# 1                 -1.487008         0.765334       0.455091
# 2                 -1.237141        -0.271834       0.383570
# 3                 -0.445896        -0.584580       0.281397
# 4                 -1.340347        -0.820736       0.271180
# ...                     ...              ...            ...
# 9653              -0.002798         1.642938       0.475526
# 9654               0.906879        -0.093122      -0.260120
# 9655              -0.471420        -0.003766       0.066834
# 9656              -1.016329        -0.916474      -0.668813
# 9657               0.275426        -0.281408      -0.873159
#
# [9658 rows x 7 columns]

# %%
data_features = data.iloc[:,-4:]
data_features
# Out:
#       perc_tackle_lt_1.5  perc_tackl_end_facing  End_dist_travel  \
# 0              -0.139697               0.087154         1.266366
# 1               0.517118              -1.487008         0.765334
# 2              -0.071583              -1.237141        -0.271834
# 3              -0.256464              -0.445896        -0.584580
# 4               0.659903              -1.340347        -0.820736
# ...                  ...                    ...              ...
# 9653            0.664244              -0.002798         1.642938
# 9654            1.962110               0.906879        -0.093122
# 9655            0.351855              -0.471420        -0.003766
# 9656            1.497757              -1.016329        -0.916474
# 9657            1.149493               0.275426        -0.281408
#
#       Max_end_speed
# 0          1.088564
# 1          0.455091
# 2          0.383570
# 3          0.281397
# 4          0.271180
# ...             ...
# 9653       0.475526
# 9654      -0.260120
# 9655       0.066834
# 9656      -0.668813
# 9657      -0.873159
#
# [9658 rows x 4 columns]

# %%
data_scaled = data
scaler = StandardScaler()
data_scaled[['perc_tackle_lt_1.5',
             'perc_tackl_end_facing',
             'End_dist_travel',
             'Max_end_speed']] = scaler.fit_transform(data_features)

# %%
data_scaled
# Out:
#         uniqueplayId  QB_Flip  end_too_far  perc_tackle_lt_1.5  \
# 0       202109090097      0.0            0           -0.139697
# 1       202109090097      1.0            0            0.517118
# 2       202109120163      0.0            0           -0.071583
# 3       202109120163      1.0            0           -0.256464
# 4       202109120288      0.0            0            0.659903
# ...              ...      ...          ...                 ...
# 9653  20211025003684      1.0            0            0.664244
# 9654  20211025003904      0.0            0            1.962110
# 9655  20211025003904      1.0            0            0.351855
# 9656  20211025003926      0.0            0            1.497757
# 9657  20211025003926      1.0            0            1.149493
#
#       perc_tackl_end_facing  End_dist_travel  Max_end_speed
# 0                  0.087154         1.266366       1.088564
# 1                 -1.487008         0.765334       0.455091
# 2                 -1.237141        -0.271834       0.383570
# 3                 -0.445896        -0.584580       0.281397
# 4                 -1.340347        -0.820736       0.271180
# ...                     ...              ...            ...
# 9653              -0.002798         1.642938       0.475526
# 9654               0.906879        -0.093122      -0.260120
# 9655              -0.471420        -0.003766       0.066834
# 9656              -1.016329        -0.916474      -0.668813
# 9657               0.275426        -0.281408      -0.873159
#
# [9658 rows x 7 columns]

# %%
kmeans = KMeans(
    init="random",
    n_clusters=2,
    n_init=10,
    max_iter=300,
    random_state=1029)

# %%
kmeans.fit(data_scaled.iloc[:,-4:])
# Out:
# KMeans(init='random', n_clusters=2, random_state=1029)

# %%
data_scaled['Cluster'] = kmeans.labels_
data_scaled
# Out:
#         uniqueplayId  QB_Flip  end_too_far  perc_tackle_lt_1.5  \
# 0       202109090097      0.0            0           -0.139697
# 1       202109090097      1.0            0            0.517118
# 2       202109120163      0.0            0           -0.071583
# 3       202109120163      1.0            0           -0.256464
# 4       202109120288      0.0            0            0.659903
# ...              ...      ...          ...                 ...
# 9653  20211025003684      1.0            0            0.664244
# 9654  20211025003904      0.0            0            1.962110
# 9655  20211025003904      1.0            0            0.351855
# 9656  20211025003926      0.0            0            1.497757
# 9657  20211025003926      1.0            0            1.149493
#
#       perc_tackl_end_facing  End_dist_travel  Max_end_speed  Cluster
# 0                  0.087154         1.266366       1.088564        0
# 1                 -1.487008         0.765334       0.455091        0
# 2                 -1.237141        -0.271834       0.383570        0
# 3                 -0.445896        -0.584580       0.281397        0
# 4                 -1.340347        -0.820736       0.271180        1
# ...                     ...              ...            ...      ...
# 9653              -0.002798         1.642938       0.475526        0
# 9654               0.906879        -0.093122      -0.260120        1
# 9655              -0.471420        -0.003766       0.066834        0
# 9656              -1.016329        -0.916474      -0.668813        1
# 9657               0.275426        -0.281408      -0.873159        1
#
# [9658 rows x 8 columns]

# %%
data_scaled['Cluster'].value_counts()
# Out:
# 0    5467
# 1    4191
# Name: Cluster, dtype: int64

# %%
data_scaled[data_scaled['uniqueplayId'] == 20211017063573]
# Out:
#         uniqueplayId  QB_Flip  end_too_far  perc_tackle_lt_1.5  \
# 8254  20211017063573      0.0            0           -0.395125
# 8255  20211017063573      1.0            0            0.298179
#
#       perc_tackl_end_facing  End_dist_travel  Max_end_speed  Cluster
# 8254               1.136596         0.851499       1.200955        0
# 8255              -1.237141         2.128013       1.599430        0

# %%
test_plays = data_scaled.sample(n = 10, random_state = 1029)
test_play_ids = test_plays['uniqueplayId'].reset_index()['uniqueplayId']

# %%
test_plays
# Out:
#         uniqueplayId  QB_Flip  end_too_far  perc_tackle_lt_1.5  \
# 5303  20210926112818      0.0            0            0.073324
# 800    2021092602494      0.0            0            0.882804
# 7493  20211010112817      1.0            0           -0.131222
# 8285  20211017071173      0.0            0           -3.029682
# 1575   2021101010874      0.0            0            0.298179
# 7991  20211017024110      0.0            0           -0.609419
# 6138  20211003081723      0.0            0           -0.103459
# 503    2021091901500      1.0            0           -0.949769
# 8748  20211021002175      0.0            0           -1.076372
# 4795  20210926051887      1.0            0           -0.533786
#
#       perc_tackl_end_facing  End_dist_travel  Max_end_speed  Cluster
# 5303              -1.711889         0.790864       0.342701        0
# 800                1.059610         0.056868      -0.740334        1
# 7493               0.217730         0.120694       0.741176        0
# 8285               1.022656        -0.970726       0.087268        0
# 1575              -0.287646         0.206859       0.199659        0
# 7991               1.266072        -0.294173      -0.770986        1
# 6138               0.792813        -0.217582       0.557264        0
# 503                0.424475        -0.077166       1.558560        0
# 8748               0.517360        -1.028169      -0.229468        1
# 4795              -0.158170        -1.143056      -0.403163        1

# %%
plays = pd.read_csv('https://media.githubusercontent.com/media/cnickol26/BigDataBowl2023/main/nfl-big-data-bowl-2023/plays.csv')

# %%
# create unique play ID for each play
plays['uniqueplayId'] = plays['gameId'].astype(str) + plays['playId'].astype(str)

# %%
plays[plays['uniqueplayId'].isin(test_play_ids.astype(str))]
# Out:
#           gameId  playId                                    playDescription  \
# 1329  2021091901     500  (6:30) (Shotgun) J.Burrow pass incomplete shor...
# 2454  2021092602     494  (8:37) (Shotgun) T.Colon reported in as eligib...
# 2689  2021092605    1887  (1:44) (Shotgun) M.Jones pass short middle to ...
# 3156  2021092611    2818  (7:23) (Shotgun) T.Brady pass short middle to ...
# 4001  2021100308    1723  (5:05) (Shotgun) J.Hurts pass short left to M....
# 5266  2021101010     874  (2:50) (Shotgun) J.Fields pass short middle to...
# 5356  2021101011    2817  (:34) (No Huddle, Shotgun) K.Murray pass short...
# 5877  2021101702    4110  (6:32) (No Huddle, Shotgun) S.Darnold pass sho...
# 6196  2021101707    1173  (12:12) (Shotgun) T.Heinicke pass short middle...
# 6638  2021102100    2175  (9:09) (Shotgun) T.Bridgewater pass short left...
#
#       quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 1329        1     3          5            CIN           CHI          CIN
# 2454        1     1         10            BAL           DET          DET
# 2689        2     1         10             NE            NO           NE
# 3156        3     1         10             TB            LA           TB
# 4001        2     1         10            PHI            KC           KC
# 5266        1     1         10            CHI            LV          CHI
# 5356        3     2          6            ARI            SF          ARI
# 5877        4     1         10            CAR           MIN          MIN
# 6196        2     1         10            WAS            KC          WAS
# 6638        3     2          8            DEN           CLE          CLE
#
#       yardlineNumber  ... absoluteYardlineNumber  offenseFormation  \
# 1329              25  ...                   35.0           SHOTGUN
# 2454              49  ...                   61.0            PISTOL
# 2689              25  ...                   35.0             EMPTY
# 3156              25  ...                   85.0           SHOTGUN
# 4001              12  ...                   22.0           SHOTGUN
# 5266              35  ...                   45.0           SHOTGUN
# 5356              40  ...                   70.0           SHOTGUN
# 5877              30  ...                   40.0           SHOTGUN
# 6196              48  ...                   58.0           SHOTGUN
# 6638              17  ...                   93.0           SHOTGUN
#
#                   personnelO defendersInBox        personnelD  dropBackType  \
# 1329        1 RB, 1 TE, 3 WR            6.0  2 DL, 3 LB, 6 DB   TRADITIONAL
# 2454  6 OL, 2 RB, 0 TE, 2 WR            7.0  3 DL, 4 LB, 4 DB   TRADITIONAL
# 2689        1 RB, 1 TE, 3 WR            5.0  3 DL, 2 LB, 6 DB   TRADITIONAL
# 3156        1 RB, 1 TE, 3 WR            6.0  2 DL, 4 LB, 5 DB   TRADITIONAL
# 4001        1 RB, 2 TE, 2 WR            6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 5266        1 RB, 3 TE, 1 WR            5.0  4 DL, 3 LB, 4 DB   TRADITIONAL
# 5356        1 RB, 1 TE, 3 WR            6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 5877        1 RB, 1 TE, 3 WR            6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 6196        1 RB, 1 TE, 3 WR            6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 6638        1 RB, 1 TE, 3 WR            6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
#
#       pff_playAction pff_passCoverage  pff_passCoverageType    uniqueplayId
# 1329               0          Cover-6                  Zone   2021091901500
# 2454               1         Quarters                  Zone   2021092602494
# 2689               0          Cover-1                   Man  20210926051887
# 3156               0          Cover-6                  Zone  20210926112818
# 4001               0         Red Zone                 Other  20211003081723
# 5266               1          Cover-3                  Zone   2021101010874
# 5356               0         Quarters                  Zone  20211010112817
# 5877               0          Cover-3                  Zone  20211017024110
# 6196               0          Cover-1                   Man  20211017071173
# 6638               0          Cover-3                  Zone  20211021002175
#
# [10 rows x 33 columns]

# %% [markdown]
# Actual rush type from watching the film (In order of test_plays)
# 1) Speed Rush (Inside)
# 2) Power
# 3) Speed
# 4) Power
# 5) Power
# 6) Power (Inside)
# 7) Power
# 8) Speed
# 9) Power
# 10) Power (Cut Block)

# %%
## Speed is 0 and power is 1
## Correctly got 7/10

# %%
plays[plays['uniqueplayId'] == '20211017063573']
# Out:
#           gameId  playId                                    playDescription  \
# 6154  2021101706    3573  (8:40) (No Huddle, Shotgun) D.Jones pass incom...
#
#       quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 6154        4     1         10            NYG            LA           LA
#
#       yardlineNumber  ... absoluteYardlineNumber  offenseFormation  \
# 6154              42  ...                   68.0           SHOTGUN
#
#             personnelO defendersInBox        personnelD  dropBackType  \
# 6154  1 RB, 2 TE, 2 WR            5.0  3 DL, 3 LB, 5 DB   TRADITIONAL
#
#       pff_playAction pff_passCoverage  pff_passCoverageType    uniqueplayId
# 6154               0          Cover-3                  Zone  20211017063573
#
# [1 rows x 33 columns]
